# %%
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pyplot as plt
from skimage.filters.thresholding import threshold_otsu

data = Image.open("dalat.jpg").convert("L")
a = np.asarray(data)
thres = threshold_otsu(a)
b = a > thres
b = Image.fromarray(b)
plt.imshow(b)
plt.show()

# %%
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pyplot as plt
from skimage.filters import threshold_local

data = Image.open("dalat.jpg").convert("L")
a = np.asarray(data)
# performing local thresholding
b = threshold_local(a, 39, offset=10)
b = Image.fromarray(b)
plt.imshow(b)
plt.show()

# %%
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pyplot as plt
from skimage.filters import threshold_local


data = cv2.imread("dalat.jpg")
a = cv2.cvtColor(data, cv2.COLOR_BGR2GRAY)
thresh, b1 = cv2.threshold(a, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
b2 = cv2.erode(b1, None, iterations=2)
dist = cv2.distanceTransform(b2, 2, 3)
thresh,dt = cv2.threshold(dist, 1, 255, cv2.THRESH_BINARY)
labelled, ncc = label(dt)
labelled = labelled.astype(np.int32)
cv2.watershed(data, labelled)
b = Image.fromarray(labelled)
plt.imshow(b)
plt.show()

# %%
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
from scipy.ndimage import label
import matplotlib.pylab as plt
from skimage.filters import threshold_local

data = Image.open('dalat.jpg').convert('L')
a = np.array(data)

thresh = threshold_otsu(a)
b = a > thresh

c = nd.binary_dilation(b, iterations = 10)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(b, cmap='gray')
plt.title("Ảnh nhị phân gốc")

plt.subplot(1, 2, 2)
plt.imshow(c, cmap='gray')
plt.title("Sau giãn ảnh (Dilation)")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import imageio.v2 as iio
import matplotlib.pylab as plt
data = iio.imread('dalat.jpg')
bmg = data[0:350, 0:500]
plt.figure(figsize=(10, 5))
iio.imsave('langbiang.jpg', bmg)
shifted = np.roll(data, 100, axis=1)
shifted[:, :100] = 0
thresh = threshold_otsu(shifted)
binary = (shifted > thresh * 0.3).astype(np.uint8) * 255
plt.subplot(1, 2, 2)
plt.title("ảnh đã cắt")
plt.imshow(bmg)

plt.subplot(1, 2, 1)
plt.title("ảnh gốc")
plt.imshow(data)
# Out:
# C:\Users\US\AppData\Local\Temp\ipykernel_32\1242707730.py:10: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (1029, 1500, 3) looks like that of an RGB image.
#   thresh = threshold_otsu(shifted)

# %%
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt
import scipy.ndimage as nd
data = iio.imread('dalat.jpg')
bmg = data[0:350, 0:500]
d1 = nd.rotate(data, 90)
plt.figure(figsize=(10, 5))
iio.imsave('langbiang.jpg', bmg)

plt.subplot(1, 2, 2)
plt.title("ảnh đã cắt")
plt.imshow(bmg)

plt.subplot(1,2,1)
plt.imshow(data)
plt.show()

# %%
import cv2
from PIL import Image
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pyplot as plt
from skimage.filters import threshold_local

# opening the image and converting it to grayscale
data = Image.open("dalat.jpg").convert("L")
# defining the structuring element
s = [[0, 1, 0], [1, 1, 1], [0, 1, 0]]
b = nd.binary_dilation(data, structure=s, iterations=25)
c = Image.fromarray(b)
plt.imshow(c)
plt.show()

# %%
# %pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/39.5 MB 8.3 MB/s eta 0:00:05
#    - -------------------------------------- 1.0/39.5 MB 3.6 MB/s eta 0:00:11
#    - -------------------------------------- 1.3/39.5 MB 2.4 MB/s eta 0:00:16
#    - -------------------------------------- 1.6/39.5 MB 2.0 MB/s eta 0:00:19
#    - -------------------------------------- 1.8/39.5 MB 1.8 MB/s eta 0:00:21
#    -- ------------------------------------- 2.1/39.5 MB 1.7 MB/s eta 0:00:23
#    -- ------------------------------------- 2.4/39.5 MB 1.6 MB/s eta 0:00:24
#    -- ------------------------------------- 2.6/39.5 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.9/39.5 MB 1.5 MB/s eta 0:00:25
#    --- ------------------------------------ 3.1/39.5 MB 1.5 MB/s eta 0:00:25
# ...
